# %%
from bs4 import BeautifulSoup
import requests
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import pandas as pd
import time
from flask import Flask, render_template

# %%
df=pd.read_excel("persone_famose.xlsx")

# %%
df=pd.read_csv('vips.csv', delimiter=';' )

# %%
df
# Out:
#         Nome      Cognome
# 0    Elettra  Lamborghini
# 1    Alessia     Marcuzzi
# 2   Michelle     Hunziker
# 3    Diletta       Leotta
# 4       Emma      Marrone
# 5    Ruggero  Pasquarelli
# 6      Laura      Pausini
# 7      Belen    Rodriguez
# 8  Francesco        Totti
# 9     Matteo      Salvini

# %%
df=df.drop(0)

# %%
df
# Out:
#         Nome      Cognome
# 1    Alessia     Marcuzzi
# 2   Michelle     Hunziker
# 3    Diletta       Leotta
# 4       Emma      Marrone
# 5    Ruggero  Pasquarelli
# 6      Laura      Pausini
# 7      Belen    Rodriguez
# 8  Francesco        Totti
# 9     Matteo      Salvini

# %%
df['enc_name']=df['Nome']+'_'+df['Cognome']
df
# Out:
#         Nome      Cognome             enc_name
# 1    Alessia     Marcuzzi     Alessia_Marcuzzi
# 2   Michelle     Hunziker    Michelle_Hunziker
# 3    Diletta       Leotta       Diletta_Leotta
# 4       Emma      Marrone         Emma_Marrone
# 5    Ruggero  Pasquarelli  Ruggero_Pasquarelli
# 6      Laura      Pausini        Laura_Pausini
# 7      Belen    Rodriguez      Belen_Rodriguez
# 8  Francesco        Totti      Francesco_Totti
# 9     Matteo      Salvini       Matteo_Salvini

# %%
base_url="https://keywordimage.com/image.php?q="

# %%
'''for i in df['nome completo']:
    name=i+'.jpeg'
    url=base_url+i+"_viso"
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")
    img_tag = soup.find("img")
    img_url = img_tag.get("src")
    f=open(name,'wb')
    response_img = requests.get(img_url)
    f.write(response_img.content)
    f.close()
    time.sleep(3)
    img = mpimg.imread(name)
    imgplot = plt.imshow(img)
    plt.title(name)
    plt.show()'''
# Out:
# 'for i in df[\'nome completo\']:\n    name=i+\'.jpeg\'\n    url=base_url+i+"_viso"\n    response = requests.get(url)\n    soup = BeautifulSoup(response.content, "html.parser")\n    img_tag = soup.find("img")\n    img_url = img_tag.get("src")\n    f=open(name,\'wb\')\n    response_img = requests.get(img_url)\n    f.write(response_img.content)\n    f.close()\n    time.sleep(3)\n    img = mpimg.imread(name)\n    imgplot = plt.imshow(img)\n    plt.title(name)\n    plt.show()'

# %%
img_urls=[]
buttons=[]
for i in df['enc_name']:
    wt=200
    ht=wt
    name=i+'.jpeg'
    url=base_url+i+"_viso"
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")
    img_tag = soup.find("img")
    img_url = img_tag.get("src")
    button=f'<a href="{img_url}" target="blank"> <button id="{i}">Visualizza intera</button> </a>'
    img_html='<img src="'+img_url+f'" height="{ht}">'
    img_urls.append(img_html)
    buttons.append(button)
    time.sleep(2)

# %%
df['img']=img_urls
df['buttons']=buttons

df['Pic']=df['img']+'<br>'+df['buttons']
df['Personaggio']=df['Nome']+' '+df['Cognome']
print(buttons)
# Out:
# ['<a href="https://www.kontrokultura.it/wp-content/uploads/2020/04/foto_alessia_marcuzzi_accusata_dai_fan.jpg" target="blank"> <button id="Alessia_Marcuzzi">Visualizza intera</button> </a>', '<a href="https://cdn.ultimenotizieflash.com/wp-content/uploads/2015/02/14182100/miuo-5.png" target="blank"> <button id="Michelle_Hunziker">Visualizza intera</button> </a>', '<a href="https://m.media-amazon.com/images/I/71J00CF1OjL._AC_SX425_.jpg" target="blank"> <button id="Diletta_Leotta">Visualizza intera</button> </a>', '<a href="https://www.today.it/~media/horizontal-hi/18423714017556/emma-marrone-6-10.jpg" target="blank"> <button id="Emma_Marrone">Visualizza intera</button> </a>', '<a href="" target="blank"> <button id="Ruggero_Pasquarelli">Visualizza intera</button> </a>', '<a href="https://lookaside.fbsbx.com/lookaside/crawler/media/?media_id=100063667992817" target="blank"> <button id="Laura_Pausini">Visualizza intera</button> </a>', '<a href="https://media-assets.vanityfair.it/photos/621359be928ce01c39c2f4d7/master/w_2333,h_3500,c_limit/GettyImages-933727058.jpg" target="blank"> <button id="Belen_Rodriguez">Visualizza intera</button> </a>', '<a href="https://pbs.twimg.com/profile_images/801423774050566144/kgy9WoSj.jpg" target="blank"> <button id="Francesco_Totti">Visualizza intera</button> </a>', '<a href="http://www.lavocedelserchio.it/public/imgcache/a6/3f231551902f10128c7f8a2dd0d520.jpg" target="blank"> <button id="Matteo_Salvini">Visualizza intera</button> </a>']

# %%
for i in buttons:
    print(i)
# Out:
# <a href="https://www.kontrokultura.it/wp-content/uploads/2020/04/foto_alessia_marcuzzi_accusata_dai_fan.jpg" target="blank"> <button id="Alessia_Marcuzzi">Visualizza intera</button> </a>
# <a href="https://cdn.ultimenotizieflash.com/wp-content/uploads/2015/02/14182100/miuo-5.png" target="blank"> <button id="Michelle_Hunziker">Visualizza intera</button> </a>
# <a href="https://m.media-amazon.com/images/I/71J00CF1OjL._AC_SX425_.jpg" target="blank"> <button id="Diletta_Leotta">Visualizza intera</button> </a>
# <a href="https://www.today.it/~media/horizontal-hi/18423714017556/emma-marrone-6-10.jpg" target="blank"> <button id="Emma_Marrone">Visualizza intera</button> </a>
# <a href="" target="blank"> <button id="Ruggero_Pasquarelli">Visualizza intera</button> </a>
# <a href="https://lookaside.fbsbx.com/lookaside/crawler/media/?media_id=100063667992817" target="blank"> <button id="Laura_Pausini">Visualizza intera</button> </a>
# <a href="https://media-assets.vanityfair.it/photos/621359be928ce01c39c2f4d7/master/w_2333,h_3500,c_limit/GettyImages-933727058.jpg" target="blank"> <button id="Belen_Rodriguez">Visualizza intera</button> </a>
# <a href="https://pbs.twimg.com/profile_images/801423774050566144/kgy9WoSj.jpg" target="blank"> <button id="Francesco_Totti">Visualizza intera</button> </a>
# <a href="http://www.lavocedelserchio.it/public/imgcache/a6/3f231551902f10128c7f8a2dd0d520.jpg" target="blank"> <button id="Matteo_Salvini">Visualizza intera</button> </a>

# %%
checkbox='<form><input type="checkbox" class="checks"></form>'
df['Arrivo']=[checkbox for i in range(0,len(df))]

# %%
df
# Out:
#         Nome      Cognome             enc_name  \
# 1    Alessia     Marcuzzi     Alessia_Marcuzzi
# 2   Michelle     Hunziker    Michelle_Hunziker
# 3    Diletta       Leotta       Diletta_Leotta
# 4       Emma      Marrone         Emma_Marrone
# 5    Ruggero  Pasquarelli  Ruggero_Pasquarelli
# 6      Laura      Pausini        Laura_Pausini
# 7      Belen    Rodriguez      Belen_Rodriguez
# 8  Francesco        Totti      Francesco_Totti
# 9     Matteo      Salvini       Matteo_Salvini
#
#                                                  img  \
# 1  <img src="https://www.kontrokultura.it/wp-cont...
# 2  <img src="https://cdn.ultimenotizieflash.com/w...
# 3  <img src="https://m.media-amazon.com/images/I/...
# 4  <img src="https://www.today.it/~media/horizont...
# 5                          <img src="" height="200">
# 6  <img src="https://lookaside.fbsbx.com/lookasid...
# 7  <img src="https://media-assets.vanityfair.it/p...
# 8  <img src="https://pbs.twimg.com/profile_images...
# 9  <img src="http://www.lavocedelserchio.it/publi...
#
#                                              buttons  \
# 1  <a href="https://www.kontrokultura.it/wp-conte...
# 2  <a href="https://cdn.ultimenotizieflash.com/wp...
# 3  <a href="https://m.media-amazon.com/images/I/7...
# 4  <a href="https://www.today.it/~media/horizonta...
# 5  <a href="" target="blank"> <button id="Ruggero...
# 6  <a href="https://lookaside.fbsbx.com/lookaside...
# 7  <a href="https://media-assets.vanityfair.it/ph...
# 8  <a href="https://pbs.twimg.com/profile_images/...
# 9  <a href="http://www.lavocedelserchio.it/public...
#
#                                                  Pic          Personaggio  \
# 1  <img src="https://www.kontrokultura.it/wp-cont...     Alessia Marcuzzi
# 2  <img src="https://cdn.ultimenotizieflash.com/w...    Michelle Hunziker
# 3  <img src="https://m.media-amazon.com/images/I/...       Diletta Leotta
# 4  <img src="https://www.today.it/~media/horizont...         Emma Marrone
# 5  <img src="" height="200"><br><a href="" target...  Ruggero Pasquarelli
# 6  <img src="https://lookaside.fbsbx.com/lookasid...        Laura Pausini
# 7  <img src="https://media-assets.vanityfair.it/p...      Belen Rodriguez
# 8  <img src="https://pbs.twimg.com/profile_images...      Francesco Totti
# 9  <img src="http://www.lavocedelserchio.it/publi...       Matteo Salvini
#
#                                               Arrivo
# 1  <form><input type="checkbox" class="checks"></...
# 2  <form><input type="checkbox" class="checks"></...
# 3  <form><input type="checkbox" class="checks"></...
# 4  <form><input type="checkbox" class="checks"></...
# 5  <form><input type="checkbox" class="checks"></...
# 6  <form><input type="checkbox" class="checks"></...
# 7  <form><input type="checkbox" class="checks"></...
# 8  <form><input type="checkbox" class="checks"></...
# 9  <form><input type="checkbox" class="checks"></...

# %%
df=df[['Pic', 'Personaggio', 'Arrivo']]

# %%
df
# Out:
#                                                  Pic          Personaggio  \
# 1  <img src="https://www.kontrokultura.it/wp-cont...     Alessia Marcuzzi
# 2  <img src="https://cdn.ultimenotizieflash.com/w...    Michelle Hunziker
# 3  <img src="https://m.media-amazon.com/images/I/...       Diletta Leotta
# 4  <img src="https://www.today.it/~media/horizont...         Emma Marrone
# 5  <img src="" height="200"><br><a href="" target...  Ruggero Pasquarelli
# 6  <img src="https://lookaside.fbsbx.com/lookasid...        Laura Pausini
# 7  <img src="https://media-assets.vanityfair.it/p...      Belen Rodriguez
# 8  <img src="https://pbs.twimg.com/profile_images...      Francesco Totti
# 9  <img src="http://www.lavocedelserchio.it/publi...       Matteo Salvini
#
#                                               Arrivo
# 1  <form><input type="checkbox" class="checks"></...
# 2  <form><input type="checkbox" class="checks"></...
# 3  <form><input type="checkbox" class="checks"></...
# 4  <form><input type="checkbox" class="checks"></...
# 5  <form><input type="checkbox" class="checks"></...
# 6  <form><input type="checkbox" class="checks"></...
# 7  <form><input type="checkbox" class="checks"></...
# 8  <form><input type="checkbox" class="checks"></...
# 9  <form><input type="checkbox" class="checks"></...

# %%
def df_to_html(df):
    #creo doc e aggiungo stile
    code='<table>'
    code+='<tr>'
    #aggiungere intestazioni
    for i in df:
        code+='<th>'
        code+=str(i)
        code+='</th>'
    code+='</tr>'
    #itero tra le righe per aggiungere i table data
    for i in df.T:
        code+='<tr>'
        for j in range(0,len(df.T[i])):
            code+='<td>'
            code+=df.T[i][j]
            code+='</td>'
        code+='</tr>'
    code+='</table>'
    
    return code

# %%
html_code=df_to_html(df)

# %%
html_code
# Out:
# '<table><tr><th>Pic</th><th>Personaggio</th><th>Arrivo</th></tr><tr><td><img src="https://www.kontrokultura.it/wp-content/uploads/2020/04/foto_alessia_marcuzzi_accusata_dai_fan.jpg" height="200"><br><a href="https://www.kontrokultura.it/wp-content/uploads/2020/04/foto_alessia_marcuzzi_accusata_dai_fan.jpg" target="blank"> <button id="Alessia_Marcuzzi">Visualizza intera</button> </a></td><td>Alessia Marcuzzi</td><td><form><input type="checkbox" class="checks"></form></td></tr><tr><td><img src="https://cdn.ultimenotizieflash.com/wp-content/uploads/2015/02/14182100/miuo-5.png" height="200"><br><a href="https://cdn.ultimenotizieflash.com/wp-content/uploads/2015/02/14182100/miuo-5.png" target="blank"> <button id="Michelle_Hunziker">Visualizza intera</button> </a></td><td>Michelle Hunziker</td><td><form><input type="checkbox" class="checks"></form></td></tr><tr><td><img src="https://m.media-amazon.com/images/I/71J00CF1OjL._AC_SX425_.jpg" height="200"><br><a href="https://m.media-amazon.com/images/I/71J00CF1OjL._AC_SX425_.jpg" target="blank"> <button id="Diletta_Leotta">Visualizza intera</button> </a></td><td>Diletta Leotta</td><td><form><input type="checkbox" class="checks"></form></td></tr><tr><td><img src="https://www.today.it/~media/horizontal-hi/18423714017556/emma-marrone-6-10.jpg" height="200"><br><a href="https://www.today.it/~media/horizontal-hi/18423714017556/emma-marrone-6-10.jpg" target="blank"> <button id="Emma_Marrone">Visualizza intera</button> </a></td><td>Emma Marrone</td><td><form><input type="checkbox" class="checks"></form></td></tr><tr><td><img src="" height="200"><br><a href="" target="blank"> <button id="Ruggero_Pasquarelli">Visualizza intera</button> </a></td><td>Ruggero Pasquarelli</td><td><form><input type="checkbox" class="checks"></form></td></tr><tr><td><img src="https://lookaside.fbsbx.com/lookaside/crawler/media/?media_id=100063667992817" height="200"><br><a href="https://lookaside.fbsbx.com/lookaside/crawler/media/?media_id=100063667992817" target="blank"> <button id="Laura_Pausini">Visualizza intera</button> </a></td><td>Laura Pausini</td><td><form><input type="checkbox" class="checks"></form></td></tr><tr><td><img src="https://media-assets.vanityfair.it/photos/621359be928ce01c39c2f4d7/master/w_2333,h_3500,c_limit/GettyImages-933727058.jpg" height="200"><br><a href="https://media-assets.vanityfair.it/photos/621359be928ce01c39c2f4d7/master/w_2333,h_3500,c_limit/GettyImages-933727058.jpg" target="blank"> <button id="Belen_Rodriguez">Visualizza intera</button> </a></td><td>Belen Rodriguez</td><td><form><input type="checkbox" class="checks"></form></td></tr><tr><td><img src="https://pbs.twimg.com/profile_images/801423774050566144/kgy9WoSj.jpg" height="200"><br><a href="https://pbs.twimg.com/profile_images/801423774050566144/kgy9WoSj.jpg" target="blank"> <button id="Francesco_Totti">Visualizza intera</button> </a></td><td>Francesco Totti</td><td><form><input type="checkbox" class="checks"></form></td></tr><tr><td><img src="http://www.lavocedelserchio.it/public/imgcache/a6/3f231551902f10128c7f8a2dd0d520.jpg" height="200"><br><a href="http://www.lavocedelserchio.it/public/imgcache/a6/3f231551902f10128c7f8a2dd0d520.jpg" target="blank"> <button id="Matteo_Salvini">Visualizza intera</button> </a></td><td>Matteo Salvini</td><td><form><input type="checkbox" class="checks"></form></td></tr></table>'
